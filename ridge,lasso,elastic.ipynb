# %%
import numpy as np
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge,Lasso,ElasticNet
from sklearn.metrics import mean_squared_error,r2_score

# %%
x , y=make_regression(n_samples=5000,n_features=10,noise=15,random_state=42)
print(x)
# Out:
# [[-2.94690422 -0.42999141  0.88898775 ... -0.033068    0.22084177
#    0.5399509 ]
#  [ 1.15435629 -0.94678406  0.48174103 ... -1.46339363  0.41225397
#   -0.095042  ]
#  [-0.83408263 -0.5275664   0.06544209 ... -1.35937989  0.21553034
#    1.05995826]
#  ...
#  [-0.08042658 -0.44350596 -0.69807775 ...  0.92646409  0.21287387
#    1.63146497]
#  [ 1.14892907  1.53517149  0.94667789 ...  1.57427105 -0.1484972
#    0.61882429]
#  [ 0.87837297  0.19050898  2.15783507 ... -1.47187384 -0.45198375
#    0.9138689 ]]

# %%
x_train,x_text,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=42)

# %%
ridge_model=Ridge(alpha=0.1)
ridge_model.fit(x_train,y_train)
y_pred_ridge=ridge_model.predict(x_text)

# %%
mse_ridge=mean_squared_error(y_test,y_pred_ridge)
r2_ridge=r2_score(y_test,y_pred_ridge)
print(mse_ridge)
print(r2_ridge)
# Out:
# 226.41673390947918
# 0.9919634192815331

# %%
elastic_model=ElasticNet(alpha=0.5,l1_ratio=0.5)
elastic_model.fit(x_train,y_train)
y_pred_elastic=elastic_model.predict(x_text)

# %%
mse_elastic=mean_squared_error(y_test,y_pred_elastic)
r2_elastic=r2_score(y_test,y_pred_elastic)
print(mse_elastic)
print(r2_elastic)
# Out:
# 1374.4409790760021
# 0.9512147106780146

# %%
lasso_model=Ridge(alpha=0.1)
lasso_model.fit(x_train,y_train)
y_pred_lasso=lasso_model.predict(x_text)

# %%
mse_lassoe=mean_squared_error(y_test,y_pred_lasso)
r2_lasso=r2_score(y_test,y_pred_ridge)
print(mse_lasso)
print(r2_lasso)
# Out:
# 226.41673390947918
# 0.9919634192815331
